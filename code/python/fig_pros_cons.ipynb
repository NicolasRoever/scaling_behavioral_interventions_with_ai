# %% [markdown]
# # Named positive and negative aspects
#
# Run the cell below to execute the complete reproducible pipeline. The model returns named aspect strings; Python counts the saved strings and creates the figure. Interrupted API runs resume from the checkpoint CSV.
#
# The public replication package excludes private interview transcripts. Before running, supply `data/private/df_clean_with_llm_themes_pros_cons_v001.csv` or set `PROS_CONS_INPUT_PATH` in `code/python/.env`.

# %%
# %run fig_pros_cons.py
